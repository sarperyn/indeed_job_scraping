# %%
import pandas as pd
import numpy as np
import nltk

# %%
df = pd.read_csv("data.csv",sep=",")

# %%
df.drop(["Unnamed: 0"],axis=1,inplace=True)

# %%
df
# Out:
#                          company  \
# 0                         Intact
# 1                         Intact
# 2                         Intact
# 3                      Microsoft
# 4                Northland Power
# ..                           ...
# 85         Side Effects Software
# 86                  Klick Health
# 87         Validere Technologies
# 88  Amazon Dev Centre Canada ULC
# 89                    StackAdapt
#
#                                            job_header  \
# 0   Data Science - 4 Month Co-op/Internship (Winte...
# 1   AI Back End Developer – 4 Month Co-op/Internsh...
# 2   ETL Developer - 4 Month Co-op/Internship (Wint...
# 3       Consulting Services: Internship Opportunities
# 4                     Intern - IT/OT Security Analyst
# ..                                                ...
# 85                         Marketing Education Intern
# 86                                         Copywriter
# 87                          Technical Success Analyst
# 88  Software Development Engineer - Supply Chain O...
# 89                                      Data Engineer
#
#                                       job_description
# 0   It’s more than a great career. It’s a bright f...
# 1   It’s more than a great career. It’s a bright f...
# 2   It’s more than a great career. It’s a bright f...
# 3   At Microsoft, Interns work on real-world proje...
# 4   We want Northland to be the first choice for t...
# ..                                                ...
# 85  Position Overview\n\nSideFX is currently looki...
# 86  About Klick Health\nMeet a different kind of w...
# 87  Who we are:\n\nValidere is a leading data and ...
# 88  2+ years of non-internship professional softwa...
# 89  StackAdapt is the no. 1 performing programmati...
#
# [90 rows x 3 columns]

# %% [markdown]
# ## Stopwords

# %%
#nltk.download("stopwords")

# %%
from nltk.corpus import stopwords

# %%
sw = stopwords.words("english")

# %%
df["job_description"] = df["job_description"].str.replace("[^\w\s]","")

# %%
df["job_description"] = df["job_description"].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df["job_description"] = df["job_description"].apply(lambda x: " ".join(x.replace("’","'") for x in x.split()))

# %%
df["job_description"] = df["job_description"].apply(lambda x: " ".join(x for x in x.split() if x not in sw))

# %%
tokens = []
for i in range(len(df["job_description"])):
    
    token = nltk.word_tokenize(df["job_description"][i])
    tokens.append(token)

# %%
tokens
# Out:
# [['great',
#   'career',
#   'bright',
#   'future',
#   'aim',
#   'best',
#   'insurance',
#   'ai',
#   'shop',
#   'world',
#   'cultivating',
#   'next',
#   'generation',
#   'tech',
#   'talent',
#   'help',
#   'us',
#   'team',
#   'youll',
#   'get',
#   'valuable',
#   'handson',
#   'industry',
#   'experience',
#   'plus',
#   'opportunity',
#   'fasttrack',
#   'career',
#   'data',
#   'science',
#   'intact',
#   'leading',
#   'insurance',
#   'transformation',
#   'better',
#   'protect',
#   'people',
#   'businesses',
#   'society',
#   'want',
#   'future',
#   'leaders',
#   'like',
#   'help',
#   'us',
#   'lead',
#   'charge',
#   'join',
#   'intact',
#   'lab',
#   'data',
#   'science',
#   'team',
#   'data',
#   'science',
#   'coopintern',
#   'role',
#   'youll',
#   'make',
#   'difference',
#   'building',
#   'skills',
#   'experience',
#   'propel',
#   'career',
#   'forward',
#   'role',
#   'cultivate',
#   'environment',
#   'help',
#   'meet',
#   'full',
#   'potential',
#   'youll',
#   'encouraged',
#   'seize',
#   'challenges',
#   'learn',
#   'diverse',
#   'teams',
#   'grow',
#   'valued',
#   'member',
#   'team',
#   'youll',
#   'get',
#   'handson',
#   'business',
#   'experience',
#   'onthejob',
#   'coaching',
#   'opportunities',
#   'build',
#   'relationships',
#   'thats',
#   'develop',
#   'future',
#   'leaders',
#   'continue',
#   'deliver',
#   'purpose',
#   'help',
#   'people',
#   'businesses',
#   'society',
#   'prosper',
#   'good',
#   'times',
#   'resilient',
#   'bad',
#   'times',
#   'data',
#   'science',
#   'coopintern',
#   'take',
#   'stimulating',
#   'projects',
#   'offer',
#   'opportunities',
#   'learn',
#   'grow',
#   'part',
#   'multidisciplinary',
#   'team',
#   'mandate',
#   'develop',
#   'roll',
#   'innovative',
#   'products',
#   'click',
#   'watch',
#   'video',
#   'intactlab',
#   'datascience',
#   'team',
#   'helping',
#   'transform',
#   'way',
#   'millions',
#   'canadians',
#   'protect',
#   'things',
#   'love',
#   'may',
#   'good',
#   'fit',
#   'role',
#   'strong',
#   'analytical',
#   'problemsolving',
#   'skills',
#   'effective',
#   'communicator',
#   'well',
#   'organized',
#   'good',
#   'time',
#   'management',
#   'skills',
#   'able',
#   'work',
#   'independently',
#   'creative',
#   'comfortable',
#   'working',
#   'part',
#   'team',
#   'youll',
#   'transform',
#   'complex',
#   'data',
#   'sets',
#   'meaningful',
#   'conclusions',
#   'recommendations',
#   'participate',
#   'developing',
#   'completely',
#   'new',
#   'innovative',
#   'solutions',
#   'using',
#   'machine',
#   'learning',
#   'ai',
#   'statistical',
#   'approaches',
#   'get',
#   'experience',
#   'working',
#   'different',
#   'types',
#   'data',
#   'including',
#   'telematics',
#   'text',
#   'data',
#   'image',
#   'data',
#   'lookout',
#   'new',
#   'approaches',
#   'opportunities',
#   'integrate',
#   'solutions',
#   'design',
#   'reasons',
#   'others',
#   'joined',
#   'team',
#   'experience',
#   'firsthand',
#   'like',
#   'work',
#   'data',
#   'scientist',
#   'learn',
#   'advances',
#   'technology',
#   'shaping',
#   'way',
#   'insurance',
#   'business',
#   'works',
#   'explore',
#   'new',
#   'ideas',
#   'learn',
#   'best',
#   'practices',
#   'fun',
#   'inclusive',
#   'environment',
#   'put',
#   'creative',
#   'mind',
#   'work',
#   'help',
#   'team',
#   'solve',
#   'problems',
#   'contribute',
#   'challenging',
#   'meaningful',
#   'projects',
#   'part',
#   'social',
#   'events',
#   'team',
#   'meet',
#   'new',
#   'people',
#   'celebrate',
#   'successes',
#   'qualifications',
#   'bring',
#   'table',
#   'bachelors',
#   'masters',
#   'phd',
#   'progress',
#   'artificial',
#   'intelligence',
#   'data',
#   'science',
#   'computer',
#   'science',
#   'mathematics',
#   'statistics',
#   'related',
#   'field',
#   'available',
#   'work',
#   'us',
#   '4',
#   'month',
#   '8',
#   'month',
#   '12',
#   'month',
#   'period',
#   'beginning',
#   'january',
#   '2022',
#   'practical',
#   'experience',
#   'data',
#   'science',
#   'machine',
#   'learning',
#   'deep',
#   'learning',
#   'practical',
#   'experience',
#   'python',
#   'r',
#   'programming',
#   'languages',
#   'knowledge',
#   'big',
#   'data',
#   'tools',
#   'spark',
#   'hadoop',
#   'asset',
#   'knowledge',
#   'computer',
#   'visioning',
#   'natural',
#   'language',
#   'processing',
#   'nlp',
#   'asset',
#   'understanding',
#   'data',
#   'science',
#   'approaches',
#   'consumer',
#   'research',
#   'domains',
#   'asset',
#   'career',
#   'starts',
#   'apply',
#   'today',
#   'cant',
#   'wait',
#   'learn',
#   'complete',
#   'application',
#   'remember',
#   'include',
#   'cover',
#   'letter',
#   'resume',
#   'university',
#   'transcript',
#   'links',
#   'personal',
#   'projects',
#   'developed',
#   'hire',
#   'coops',
#   'every',
#   'semester',
#   'winter',
#   'summer',
#   'fall',
#   'accepting',
#   'applications',
#   'october',
#   '8',
#   '2021',
#   '1159pm',
#   'est',
#   'submissions',
#   'reviewed',
#   'time',
#   'well',
#   'posting',
#   'closes',
#   'flexible',
#   'work',
#   'arrangements',
#   'right',
#   'support',
#   '100',
#   'remote',
#   'work',
#   'role',
#   'permits',
#   'anticipate',
#   'november',
#   'well',
#   'moving',
#   'hybrid',
#   'approach',
#   'gives',
#   'us',
#   'best',
#   'worlds',
#   'mix',
#   'home',
#   'inoffice',
#   'workdays',
#   'closing',
#   'statement',
#   'equal',
#   'opportunity',
#   'employer',
#   'intact',
#   'value',
#   'respect',
#   'founded',
#   'seeing',
#   'diversity',
#   'strength',
#   'inclusive',
#   'fostering',
#   'collaboration',
#   'value',
#   'diversity',
#   'strive',
#   'create',
#   'inclusive',
#   'accessible',
#   'workplace',
#   'individuals',
#   'feel',
#   'valued',
#   'respected',
#   'heard',
#   'provide',
#   'specific',
#   'adjustment',
#   'make',
#   'recruitment',
#   'process',
#   'accessible',
#   'please',
#   'advise',
#   'talent',
#   'acquisition',
#   'partner',
#   'reaches',
#   'job',
#   'opportunity',
#   'work',
#   'meet',
#   'needs',
#   'background',
#   'checks',
#   'employer',
#   'publicly',
#   'traded',
#   'financial',
#   'services',
#   'company',
#   'best',
#   'interests',
#   'customers',
#   'employees',
#   'shareholders',
#   'important',
#   'us',
#   'want',
#   'intact',
#   'great',
#   'place',
#   'work',
#   'means',
#   'internal',
#   'external',
#   'candidates',
#   'asked',
#   'consent',
#   'background',
#   'checks',
#   'learn',
#   'please',
#   'note',
#   'positions',
#   'access',
#   'financial',
#   'data',
#   'funds',
#   'credit',
#   'must',
#   'good',
#   'standing',
#   'internal',
#   'candidates',
#   'internal',
#   'candidates',
#   'apply',
#   'posted',
#   'position',
#   'current',
#   'position',
#   'least',
#   '12',
#   'months',
#   'performing',
#   'satisfactory',
#   'level',
#   'please',
#   'note',
#   'may',
#   'identified',
#   'internal',
#   'candidates',
#   'employee',
#   'development',
#   'program',
#   'selection',
#   'process',
#   'may',
#   'also',
#   'opened',
#   'external',
#   'applicants',
#   'eligibility',
#   'work',
#   'canada',
#   'important',
#   'legally',
#   'eligible',
#   'work',
#   'canada',
#   'time',
#   'offer',
#   'employment',
#   'made',
#   'may',
#   'requested',
#   'provide',
#   'proof',
#   'eligibility',
#   'time',
#   'student',
#   'relations',
#   'studentrelations'],
#  ['great',
#   'career',
#   'bright',
#   'future',
#   'looking',
#   'gain',
#   'invaluable',
#   'industry',
#   'experience',
#   'fasttrack',
#   'exciting',
#   'career',
#   'intact',
#   'leading',
#   'insurance',
#   'transformation',
#   'better',
#   'protect',
#   'people',
#   'businesses',
#   'society',
#   'want',
#   'future',
#   'leaders',
#   'like',
#   'help',
#   'us',
#   'lead',
#   'charge',
#   'join',
#   'artificial',
#   'intelligent',
#   'team',
#   'backend',
#   'developer',
#   'winter',
#   '2022',
#   'term',
#   'role',
#   'youll',
#   'make',
#   'difference',
#   'building',
#   'skills',
#   'experience',
#   'propel',
#   'career',
#   'forward',
#   'role',
#   'cultivate',
#   'environment',
#   'help',
#   'meet',
#   'full',
#   'potential',
#   'youll',
#   'encouraged',
#   'seize',
#   'challenges',
#   'learn',
#   'diverse',
#   'teams',
#   'grow',
#   'valued',
#   'member',
#   'team',
#   'youll',
#   'get',
#   'handson',
#   'business',
#   'experience',
#   'onthejob',
#   'coaching',
#   'opportunities',
#   'build',
#   'relationships',
#   'thats',
#   'develop',
#   'future',
#   'leaders',
#   'continue',
#   'deliver',
#   'purpose',
#   'help',
#   'people',
#   'businesses',
#   'society',
#   'prosper',
#   'good',
#   'times',
#   'resilient',
#   'bad',
#   'times',
#   'youll',
#   'design',
#   'test',
#   'develop',
#   'backend',
#   'solutions',
#   'artificial',
#   'intelligence',
#   'teams',
#   'stay',
#   'current',
#   'new',
#   'approaches',
#   'opportunities',
#   'bring',
#   'solutions',
#   'design',
#   'help',
#   'transforming',
#   'complex',
#   'data',
#   'sets',
#   'meaningful',
#   'conclusions',
#   'recommendation',
#   'work',
#   'agile',
#   'team',
#   'develop',
#   'major',
#   'systems',
#   'using',
#   'latest',
#   'internet',
#   'application',
#   'technologies',
#   'find',
#   'technical',
#   'solutions',
#   'brainstorming',
#   'team',
#   'members',
#   'building',
#   'prototypes',
#   'necessary',
#   'prepare',
#   'technical',
#   'documentation',
#   'deploy',
#   'support',
#   'completed',
#   'systems',
#   'develop',
#   'perform',
#   'unit',
#   'tests',
#   'validate',
#   'code',
#   'provide',
#   'advice',
#   'support',
#   'teams',
#   'production',
#   'skills',
#   'transfer',
#   'provide',
#   'estimates',
#   'status',
#   'reports',
#   'needed',
#   'keep',
#   'date',
#   'new',
#   'technologies',
#   'introduce',
#   'new',
#   'practical',
#   'approaches',
#   'reasons',
#   'others',
#   'joined',
#   'team',
#   'awardwinning',
#   'inspiring',
#   'workplace',
#   'supports',
#   'people',
#   'recognizes',
#   'great',
#   'work',
#   'stimulating',
#   'challenging',
#   'projects',
#   'development',
#   'opportunities',
#   'help',
#   'grow',
#   'skills',
#   'career',
#   'qualifications',
#   'bring',
#   'table',
#   'currently',
#   'pursuing',
#   'university',
#   'degree',
#   'software',
#   'engineering',
#   'computer',
#   'science',
#   'available',
#   'work',
#   'us',
#   'fulltime',
#   'winter',
#   '2022',
#   'term',
#   'january',
#   'april',
#   '1',
#   'terms',
#   'relevant',
#   'internship',
#   'experience',
#   'objectoriented',
#   'programming',
#   'skills',
#   'experience',
#   'python',
#   'java',
#   'programming',
#   'interest',
#   'javakotlin',
#   'dockerkubernetes',
#   'hazelcastredis',
#   'spring',
#   'bootspring',
#   'cloud',
#   'mongodboracle',
#   'technologies',
#   'knowledge',
#   'development',
#   'design',
#   'patterns',
#   'knowledge',
#   'interest',
#   'artificial',
#   'intelligence',
#   'understand',
#   'basics',
#   'agile',
#   'way',
#   'work',
#   'good',
#   'understanding',
#   'entire',
#   'software',
#   'development',
#   'lifecycle',
#   'bilingualism',
#   'asset',
#   'french',
#   'english',
#   'career',
#   'starts',
#   'apply',
#   'today',
#   'cant',
#   'wait',
#   'learn',
#   'complete',
#   'application',
#   'remember',
#   'include',
#   'cover',
#   'letter',
#   'resume',
#   'university',
#   'transcript',
#   'links',
#   'personal',
#   'projects',
#   'developed',
#   'hire',
#   'coops',
#   'every',
#   'semester',
#   'winter',
#   'summer',
#   'fall',
#   'accepting',
#   'applications',
#   'october',
#   '8',
#   '2021',
#   '1159pm',
#   'est',
#   'submissions',
#   'reviewed',
#   'time',
#   'well',
#   'posting',
#   'closes',
#   'flexible',
#   'work',
#   'arrangements',
#   'right',
#   'support',
#   '100',
#   'remote',
#   'work',
#   'role',
#   'permits',
#   'anticipate',
#   'november',
#   'well',
#   'moving',
#   'hybrid',
#   'approach',
#   'gives',
#   'us',
#   'best',
#   'worlds',
#   'mix',
#   'home',
#   'inoffice',
#   'workdays',
#   'closing',
#   'statement',
#   'equal',
#   'opportunity',
#   'employer',
#   'intact',
#   'value',
#   'respect',
#   'founded',
#   'seeing',
#   'diversity',
#   'strength',
#   'inclusive',
#   'fostering',
#   'collaboration',
#   'value',
#   'diversity',
#   'strive',
#   'create',
#   'inclusive',
#   'accessible',
#   'workplace',
#   'individuals',
#   'feel',
#   'valued',
#   'respected',
#   'heard',
#   'provide',
#   'specific',
#   'adjustment',
#   'make',
#   'recruitment',
#   'process',
#   'accessible',
#   'please',
#   'advise',
#   'talent',
#   'acquisition',
#   'partner',
#   'reaches',
#   'job',
#   'opportunity',
#   'work',
#   'meet',
#   'needs',
#   'background',
#   'checks',
#   'employer',
#   'publicly',
#   'traded',
#   'financial',
#   'services',
#   'company',
#   'best',
#   'interests',
#   'customers',
#   'employees',
#   'shareholders',
#   'important',
#   'us',
#   'want',
#   'intact',
#   'great',
#   'place',
#   'work',
#   'means',
#   'internal',
#   'external',
#   'candidates',
#   'asked',
#   'consent',
#   'background',
#   'checks',
#   'learn',
#   'please',
#   'note',
#   'positions',
#   'access',
#   'financial',
#   'data',
#   'funds',
#   'credit',
#   'must',
#   'good',
#   'standing',
#   'internal',
#   'candidates',
#   'internal',
#   'candidates',
#   'apply',
#   'posted',
#   'position',
#   'current',
#   'position',
#   'least',
#   '12',
#   'months',
#   'performing',
#   'satisfactory',
#   'level',
#   'please',
#   'note',
#   'may',
#   'identified',
#   'internal',
#   'candidates',
#   'employee',
#   'development',
#   'program',
#   'selection',
#   'process',
#   'may',
#   'also',
#   'opened',
#   'external',
#   'applicants',
#   'eligibility',
#   'work',
#   'canada',
#   'important',
#   'legally',
#   'eligible',
#   'work',
#   'canada',
#   'time',
#   'offer',
#   'employment',
#   'made',
#   'may',
#   'requested',
#   'provide',
#   'proof',
#   'eligibility',
#   'time',
#   'student',
#   'relations',
#   'studentrelations'],
#  ['great',
#   'career',
#   'bright',
#   'future',
#   'looking',
#   'gain',
#   'invaluable',
#   'industry',
#   'experience',
#   'fasttrack',
#   'exciting',
#   'career',
#   'intact',
#   'leading',
#   'insurance',
#   'transformation',
#   'better',
#   'protect',
#   'people',
#   'businesses',
#   'society',
#   'want',
#   'future',
#   'leaders',
#   'like',
#   'help',
#   'us',
#   'lead',
#   'charge',
#   'opportunity',
#   'join',
#   'data',
#   'analytics',
#   'team',
#   'etl',
#   'developer',
#   'coopintern',
#   'winter',
#   '2022',
#   'term',
#   'role',
#   'youll',
#   'make',
#   'difference',
#   'building',
#   'skills',
#   'experience',
#   'propel',
#   'career',
#   'forward',
#   'role',
#   'cultivate',
#   'environment',
#   'help',
#   'meet',
#   'full',
#   'potential',
#   'youll',
#   'encouraged',
#   'seize',
#   'challenges',
#   'learn',
#   'diverse',
#   'teams',
#   'grow',
#   'valued',
#   'member',
#   'team',
#   'youll',
#   'get',
#   'handson',
#   'business',
#   'experience',
#   'onthejob',
#   'coaching',
#   'opportunities',
#   'build',
#   'relationships',
#   'thats',
#   'develop',
#   'future',
#   'leaders',
#   'continue',
#   'deliver',
#   'purpose',
#   'help',
#   'people',
#   'businesses',
#   'society',
#   'prosper',
#   'good',
#   'times',
#   'resilient',
#   'bad',
#   'times',
#   'youll',
#   'participate',
#   'design',
#   'component',
#   'datawarehouse',
#   'system',
#   'development',
#   'team',
#   'program',
#   'modify',
#   'test',
#   'debug',
#   'data',
#   'collection',
#   'systems',
#   'extraction',
#   'processing',
#   'loading',
#   'programs',
#   'produce',
#   'quality',
#   'evidence',
#   'create',
#   'maintain',
#   'system',
#   'documentation',
#   'reasons',
#   'others',
#   'joined',
#   'team',
#   'awardwinning',
#   'inspiring',
#   'workplace',
#   'supports',
#   'people',
#   'recognizes',
#   'great',
#   'work',
#   'stimulating',
#   'challenging',
#   'projects',
#   'development',
#   'opportunities',
#   'help',
#   'grow',
#   'skills',
#   'career',
#   'qualifications',
#   'bring',
#   'table',
#   'currently',
#   'pursuing',
#   'bachelors',
#   'degree',
#   'computer',
#   'sciences',
#   'data',
#   'sciences',
#   'related',
#   'field',
#   'available',
#   'work',
#   'us',
#   'winter',
#   '2022',
#   'january',
#   'april',
#   'must',
#   'returning',
#   'full',
#   'time',
#   'studies',
#   'following',
#   'internship',
#   '2022',
#   'understand',
#   'technical',
#   'business',
#   'characteristics',
#   'system',
#   'experience',
#   'different',
#   'database',
#   'concepts',
#   'relational',
#   'models',
#   'development',
#   'experience',
#   'oracle',
#   'informatica',
#   'powerexchange',
#   'sas',
#   'snowflake',
#   'experience',
#   'languages',
#   'sas',
#   'sql',
#   'plsql',
#   'xml',
#   'javascript',
#   'python',
#   'spark',
#   'bi',
#   'experience',
#   'power',
#   'bi',
#   'sap',
#   'business',
#   'object',
#   'sas',
#   'eg',
#   'databricks',
#   'snowflake',
#   'equivalent',
#   'team',
#   'player',
#   'eager',
#   'learn',
#   'career',
#   'starts',
#   'apply',
#   'today',
#   'cant',
#   'wait',
#   'learn',
#   'complete',
#   'application',
#   'remember',
#   'include',
#   'cover',
#   'letter',
#   'resume',
#   'universitycollege',
#   'transcript',
#   'accepting',
#   'applications',
#   'october',
#   '8',
#   '2021',
#   '1159pm',
#   'est',
#   'submissions',
#   'reviewed',
#   'time',
#   'well',
#   'posting',
#   'closes',
#   'flexible',
#   'work',
#   'arrangements',
#   'right',
#   'support',
#   '100',
#   'remote',
#   'work',
#   'role',
#   'permits',
#   'anticipate',
#   'november',
#   'well',
#   'moving',
#   'hybrid',
#   'approach',
#   'gives',
#   'us',
#   'best',
#   'worlds',
#   'mix',
#   'home',
#   'inoffice',
#   'workdays',
#   'closing',
#   'statement',
#   'equal',
#   'opportunity',
#   'employer',
#   'intact',
#   'value',
#   'respect',
#   'founded',
#   'seeing',
#   'diversity',
#   'strength',
#   'inclusive',
#   'fostering',
#   'collaboration',
#   'value',
#   'diversity',
#   'strive',
#   'create',
#   'inclusive',
#   'accessible',
#   'workplace',
#   'individuals',
#   'feel',
#   'valued',
#   'respected',
#   'heard',
#   'provide',
#   'specific',
#   'adjustment',
#   'make',
#   'recruitment',
#   'process',
#   'accessible',
#   'please',
#   'advise',
#   'talent',
#   'acquisition',
#   'partner',
#   'reaches',
#   'job',
#   'opportunity',
#   'work',
#   'meet',
#   'needs',
#   'background',
#   'checks',
#   'employer',
#   'publicly',
#   'traded',
#   'financial',
#   'services',
#   'company',
#   'best',
#   'interests',
#   'customers',
#   'employees',
#   'shareholders',
#   'important',
#   'us',
#   'want',
#   'intact',
#   'great',
#   'place',
#   'work',
#   'means',
#   'internal',
#   'external',
#   'candidates',
#   'asked',
#   'consent',
#   'background',
#   'checks',
#   'learn',
#   'please',
#   'note',
#   'positions',
#   'access',
#   'financial',
#   'data',
#   'funds',
#   'credit',
#   'must',
#   'good',
#   'standing',
#   'internal',
#   'candidates',
#   'internal',
#   'candidates',
#   'apply',
#   'posted',
#   'position',
#   'current',
#   'position',
#   'least',
#   '12',
#   'months',
#   'performing',
#   'satisfactory',
#   'level',
#   'please',
#   'note',
#   'may',
#   'identified',
#   'internal',
#   'candidates',
#   'employee',
#   'development',
#   'program',
#   'selection',
#   'process',
#   'may',
#   'also',
#   'opened',
#   'external',
#   'applicants',
#   'eligibility',
#   'work',
#   'canada',
#   'important',
#   'legally',
#   'eligible',
#   'work',
#   'canada',
#   'time',
#   'offer',
#   'employment',
#   'made',
#   'may',
#   'requested',
#   'provide',
#   'proof',
#   'eligibility',
#   'time',
#   'student',
#   'relations',
#   'studentrelations'],
#  ['microsoft',
#   'interns',
#   'work',
#   'realworld',
#   'projects',
#   'collaboration',
#   'teams',
#   'across',
#   'world',
#   'fun',
#   'along',
#   'way',
#   'youll',
#   'empowered',
#   'build',
#   'community',
#   'explore',
#   'passion',
#   'achieve',
#   'goals',
#   'chance',
#   'bring',
#   'solutions',
#   'ideas',
#   'life',
#   'working',
#   'cuttingedge',
#   'technology',
#   'internship',
#   'designed',
#   'great',
#   'work',
#   'opportunity',
#   'learn',
#   'grow',
#   'experience',
#   'culture',
#   'full',
#   'diverse',
#   'community',
#   'connection',
#   'executive',
#   'engagement',
#   'memorable',
#   'events',
#   'imagine',
#   'microsoft',
#   'intern',
#   'join',
#   'microsoft',
#   'today',
#   'help',
#   'us',
#   'innovate',
#   'shape',
#   'business',
#   'tomorrow',
#   'company',
#   'learnitalls',
#   'rather',
#   'knowitalls',
#   'culture',
#   'centered',
#   'around',
#   'embracing',
#   'growth',
#   'mindset',
#   'theme',
#   'inspiring',
#   'excellence',
#   'encouraging',
#   'teams',
#   'leaders',
#   'bring',
#   'best',
#   'day',
#   'sound',
#   'like',
#   'learn',
#   'cultural',
#   'attributes',
#   'ready',
#   'join',
#   'us',
#   'create',
#   'future',
#   'come',
#   'lovestart',
#   'journey',
#   'us',
#   'today',
#   'responsibilities',
#   'role',
#   'description',
#   'applications',
#   'opportunities',
#   'considered',
#   'available',
#   'consulting',
#   'services',
#   'intern',
#   'roles',
#   'including',
#   'limited',
#   'role',
#   'described',
#   'consultant',
#   'consultants',
#   'strategists',
#   'work',
#   'closely',
#   'microsofts',
#   'partners',
#   'assist',
#   'customers',
#   'delivery',
#   'highquality',
#   'engagements',
#   'around',
#   'microsofts',
#   'solution',
#   'areas',
#   'technologies',
#   'services',
#   'products',
#   'diverse',
#   'client',
#   'environments',
#   'responsibilities',
#   'contributes',
#   'presales',
#   'process',
#   'leveraging',
#   'knowledge',
#   'business',
#   'requirements',
#   'successfully',
#   'offer',
#   'technical',
#   'input',
#   'solution',
#   'offerings',
#   'participates',
#   'project',
#   'planning',
#   'identifying',
#   'risks',
#   'dependencies',
#   'proposing',
#   'appropriate',
#   'mitigations',
#   'implements',
#   'technical',
#   'solutions',
#   'coordinating',
#   'aligning',
#   'customers',
#   'business',
#   'goals',
#   'cultivates',
#   'relationships',
#   'customers',
#   'partners',
#   'stakeholders',
#   'identify',
#   'drivers',
#   'satisfaction',
#   'establish',
#   'recovery',
#   'actions',
#   'improve',
#   'experience',
#   'project',
#   'manager',
#   'project',
#   'managers',
#   'pjm',
#   'unique',
#   'mix',
#   'project',
#   'management',
#   'consulting',
#   'skills',
#   'driven',
#   'passion',
#   'technology',
#   'pjm',
#   'ensures',
#   'projects',
#   'successfully',
#   'delivered',
#   'customers',
#   'time',
#   'meeting',
#   'specifications',
#   'responsibilities',
#   'drives',
#   'project',
#   'initiation',
#   'prioritizing',
#   'tasks',
#   'proactively',
#   'removing',
#   'risks',
#   'creating',
#   'work',
#   'breakdown',
#   'structures',
#   'develops',
#   'project',
#   'management',
#   'plan',
#   'drive',
#   'project',
#   'delivery',
#   'line',
#   'customer',
#   'needs',
#   'leverages',
#   'technical',
#   'expertise',
#   'engage',
#   'customer',
#   'stakeholders',
#   'cultivate',
#   'business',
#   'relationships',
#   'builds',
#   'trusted',
#   'relationships',
#   'customers',
#   'reviewing',
#   'feedback',
#   'providing',
#   'guidance',
#   'managing',
#   'expectations',
#   'adhering',
#   'key',
#   'performance',
#   'indicators',
#   'pursuit',
#   'lead',
#   'overview',
#   'pursuit',
#   'leads',
#   'key',
#   'participants',
#   'driving',
#   'sales',
#   'growth',
#   'solutions',
#   'provide',
#   'leadership',
#   'domain',
#   'assigned',
#   'resources',
#   'activities',
#   'support',
#   'opportunity',
#   'qualification',
#   'scoping',
#   'estimating',
#   'costing',
#   'risk',
#   'identification',
#   'mitigations',
#   'contract',
#   'preparation',
#   'delivery',
#   'contracted',
#   'work',
#   'delivery',
#   'teams',
#   'responsibilities',
#   'defines',
#   'shapes',
#   'scopes',
#   'quality',
#   'solutions',
#   'satisfy',
#   'customer',
#   'requirements',
#   'drive',
#   'business',
#   'outcomes',
#   'presales',
#   'collaborates',
#   'sales',
#   'domain',
#   'create',
#   'execute',
#   'combined',
#   'opportunity',
#   'close',
#   'plan',
#   'outlines',
#   'owners',
#   'actions',
#   'drives',
#   'deal',
#   'velocity',
#   'works',
#   'pursuit',
#   'team',
#   'balance',
#   'customer',
#   'expectations',
#   'microsoft',
#   'business',
#   'goals',
#   'mitigating',
#   'risk',
#   'maximizing',
#   'delivery',
#   'best',
#   'practices',
#   'applying',
#   'right',
#   'shoring',
#   'delivery',
#   'mix',
#   'capabilities',
#   'appropriate',
#   'deal',
#   'complexity',
#   'qualifications',
#   'basic',
#   'qualifications',
#   'currently',
#   'pursuing',
#   'bachelors',
#   'degree',
#   'computer',
#   'science',
#   'information',
#   'technology',
#   'engineering',
#   'related',
#   'field',
#   'least',
#   'one',
#   'semesterquarter',
#   'remaining',
#   'internship',
#   'passion',
#   'technology',
#   'customer',
#   'obsessed',
#   'displays',
#   'strong',
#   'stakeholder',
#   'relationship',
#   'management',
#   'skills',
#   'excellent',
#   'verbal',
#   'written',
#   'communication',
#   'analytical',
#   'presentation',
#   'skills',
#   'microsoft',
#   'product',
#   'certification',
#   'mcse',
#   'technical',
#   'certifications',
#   'plus',
#   'visit',
#   'careers',
#   'faq',
#   'page',
#   'learn',
#   'interview',
#   'process',
#   'answers',
#   'commonly',
#   'asked',
#   'questions',
#   'microsoft',
#   'equal',
#   'opportunity',
#   'employer',
#   'qualified',
#   'applicants',
#   'receive',
#   'consideration',
#   'employment',
#   'without',
#   'regard',
#   'age',
#   'ancestry',
#   'color',
#   'family',
#   'medical',
#   'care',
#   'leave',
#   'gender',
#   'identity',
#   'expression',
#   'genetic',
#   'information',
#   'marital',
#   'status',
#   'medical',
#   'condition',
#   'national',
#   'origin',
#   'physical',
#   'mental',
#   'disability',
#   'political',
#   'affiliation',
#   'protected',
#   'veteran',
#   'status',
#   'race',
#   'religion',
#   'sex',
#   'including',
#   'pregnancy',
#   'sexual',
#   'orientation',
#   'characteristic',
#   'protected',
#   'applicable',
#   'laws',
#   'regulations',
#   'ordinances',
#   'also',
#   'consider',
#   'qualified',
#   'applicants',
#   'regardless',
#   'criminal',
#   'histories',
#   'consistent',
#   'legal',
#   'requirements',
#   'need',
#   'assistance',
#   'andor',
#   'reasonable',
#   'accommodation',
#   'due',
#   'disability',
#   'application',
#   'recruiting',
#   'process',
#   'please',
#   'send',
#   'request',
#   'via',
#   'accommodation',
#   'request',
#   'form',
#   'benefitsperks',
#   'listed',
#   'may',
#   'vary',
#   'depending',
#   'nature',
#   'employment',
#   'microsoft',
#   'country',
#   'work'],
#  ['want',
#   'northland',
#   'first',
#   'choice',
#   'talented',
#   'people',
#   'looking',
#   'rewarding',
#   'challenging',
#   'career',
#   'workforce',
#   'diverse',
#   'team',
#   'individuals',
#   'broad',
#   'multifaceted',
#   'skill',
#   'set',
#   'dedicated',
#   'delivering',
#   'results',
#   'stakeholders',
#   'upholding',
#   'values',
#   'culture',
#   'mike',
#   'crawley',
#   'president',
#   'ceo',
#   'reporting',
#   'director',
#   'itot',
#   'security',
#   'compliance',
#   'itot',
#   'security',
#   'analyst',
#   'internship',
#   'responsible',
#   'assisting',
#   'daytoday',
#   'itot',
#   'security',
#   'operations',
#   'including',
#   'implementation',
#   'security',
#   'projects',
#   'ensuring',
#   'success',
#   'daytoday',
#   'operations',
#   'assisting',
#   'itot',
#   'teams',
#   'business',
#   'units',
#   'security',
#   'related',
#   'tasks',
#   'role',
#   'responsible',
#   'working',
#   'closely',
#   'global',
#   'teams',
#   'managed',
#   'service',
#   'partners',
#   'ensure',
#   'security',
#   'ot',
#   'assets',
#   'role',
#   'responsible',
#   'assisting',
#   'implementation',
#   'andor',
#   'administration',
#   'several',
#   'technologies',
#   'including',
#   'security',
#   'orchestration',
#   'endpoint',
#   'security',
#   'network',
#   'security',
#   'vulnerability',
#   'management',
#   'thirdparty',
#   'risk',
#   'management',
#   'security',
#   'incident',
#   'event',
#   'management',
#   'system',
#   'security',
#   'awareness',
#   'training',
#   'platform',
#   'vpn',
#   'threat',
#   'intelligence',
#   'privileged',
#   'access',
#   'management',
#   'system',
#   'key',
#   'accountabilitiesresponsibilities',
#   'responsible',
#   'assisting',
#   'implementation',
#   'monitoring',
#   'global',
#   'cyber',
#   'security',
#   'program',
#   'governs',
#   'northland',
#   'entities',
#   'includes',
#   'information',
#   'technology',
#   'operations',
#   'technology',
#   'responsible',
#   'assisting',
#   'evaluation',
#   'implementation',
#   'documentation',
#   'security',
#   'controls',
#   'support',
#   'global',
#   'cyber',
#   'security',
#   'program',
#   'including',
#   'limited',
#   'around',
#   'intrusion',
#   'detection',
#   'endpoint',
#   'security',
#   'segmentation',
#   'email',
#   'security',
#   'siem',
#   'security',
#   'orchestration',
#   'automation',
#   'data',
#   'loss',
#   'prevention',
#   'authentication',
#   'controls',
#   'web',
#   'filtering',
#   'threat',
#   'intelligence',
#   'office',
#   '365',
#   'responsible',
#   'assisting',
#   'maintenance',
#   'security',
#   'systems',
#   'ensure',
#   'remain',
#   'date',
#   'identify',
#   'prevent',
#   'threats',
#   'responsible',
#   'assisting',
#   'implementing',
#   'procedures',
#   'technology',
#   'changes',
#   'maintain',
#   'evolve',
#   'northlands',
#   'security',
#   'maturity',
#   'responsible',
#   'assisting',
#   'monitoring',
#   'reporting',
#   'network',
#   'security',
#   'system',
#   'application',
#   'security',
#   'solutions',
#   'highlight',
#   'areas',
#   'noncompliance',
#   'recommend',
#   'development',
#   'improved',
#   'practices',
#   'processes',
#   'provides',
#   'support',
#   'cybersecurity',
#   'incident',
#   'response',
#   'processes',
#   'provides',
#   'support',
#   'periodic',
#   'penetration',
#   'tests',
#   'participates',
#   'supports',
#   'teams',
#   'required',
#   'project',
#   'pipeline',
#   'activity',
#   'ensure',
#   'itot',
#   'acquisitions',
#   'implementations',
#   'line',
#   'northland',
#   'itot',
#   'security',
#   'requirements',
#   'build',
#   'relationships',
#   'work',
#   'closely',
#   'managed',
#   'service',
#   'partners',
#   'itot',
#   'infrastructure',
#   'project',
#   'management',
#   'provide',
#   'organization',
#   'direction',
#   'guidance',
#   'security',
#   'best',
#   'practices',
#   'compliance',
#   'policies',
#   'build',
#   'relationships',
#   'work',
#   'closely',
#   'managed',
#   'security',
#   'partners',
#   'soc',
#   'monitor',
#   'identify',
#   'gaps',
#   'current',
#   'environment',
#   'implement',
#   'necessary',
#   'changes',
#   'establishes',
#   'maintain',
#   'relationships',
#   'well',
#   'written',
#   'inperson',
#   'communications',
#   'key',
#   'stakeholders',
#   'security',
#   'matters',
#   'including',
#   'itot',
#   'employees',
#   'human',
#   'resources',
#   'risk',
#   'management',
#   'engineering',
#   'operations',
#   'participates',
#   'ongoing',
#   'itot',
#   'security',
#   'audits',
#   'northland',
#   'entities',
#   'ensure',
#   'compliance',
#   'baseline',
#   'requirements',
#   'provides',
#   'backup',
#   'support',
#   'itot',
#   'security',
#   'compliance',
#   'team',
#   'members',
#   'required',
#   'educationexperience',
#   'currently',
#   'enrolled',
#   'undergraduate',
#   'degree',
#   'postsecondary',
#   'diploma',
#   'computer',
#   'science',
#   'related',
#   'field',
#   'working',
#   'knowledge',
#   'security',
#   'tools',
#   'principles',
#   'practices',
#   'courses',
#   'security',
#   'network',
#   'administration',
#   'server',
#   'administration',
#   'data',
#   'protection',
#   'industrial',
#   'control',
#   'systems',
#   'highly',
#   'desirable',
#   'good',
#   'understanding',
#   'privacy',
#   'laws',
#   'relate',
#   'cyber',
#   'security',
#   'strong',
#   'analytical',
#   'problemsolving',
#   'skills',
#   'sound',
#   'knowledge',
#   'secure',
#   'network',
#   'design',
#   'lan',
#   'wan',
#   'otics',
#   'environments',
#   'network',
#   'intrusion',
#   'detection',
#   'concepts',
#   'academic',
#   'experience',
#   'working',
#   'enterprise',
#   'infrastructure',
#   'technologies',
#   'security',
#   'platforms',
#   'firewalls',
#   'siem',
#   'vulnerability',
#   'management',
#   'solutions',
#   'privileged',
#   'access',
#   'management',
#   'intrusion',
#   'detection',
#   'systems',
#   'endpoint',
#   'security',
#   'cloud',
#   'solutions',
#   'office',
#   '365',
#   'understanding',
#   'security',
#   'frameworks',
#   'iso',
#   '27000',
#   'series',
#   'nist',
#   'sp80053',
#   'nist',
#   'csf',
#   'strong',
#   'analysis',
#   'attention',
#   'detail',
#   'strong',
#   'verbalwritten',
#   'communication',
#   'presentation',
#   'skills',
#   'good',
#   'judgement',
#   'highly',
#   'selfmotivated',
#   'selfdirected',
#   'ability',
#   'effectively',
#   'prioritize',
#   'execute',
#   'tasks',
#   'pressured',
#   'situation',
#   'experience',
#   'working',
#   'teamoriented',
#   'collaborative',
#   'environment',
#   'experience',
#   'willing',
#   'work',
#   'hands',
#   'interested',
#   'dynamic',
#   'fast',
#   'paced',
#   'environment',
#   'demonstrates',
#   'passion',
#   'cybersecurity',
#   'critical',
#   'infrastructure',
#   'protection',
#   'disclaimer',
#   'document',
#   'guide',
#   'duties',
#   'responsibilities',
#   'requirements',
#   'jobs',
#   'described',
#   'herein',
#   'inclusive',
#   'subject',
#   'change',
#   'northland',
#   'power',
#   'equal',
#   'opportunity',
#   'employer',
#   'committed',
#   'creating',
#   'fair',
#   'inclusive',
#   'accessible',
#   'environment',
#   'part',
#   'commitment',
#   'work',
#   'ensure',
#   'application',
#   'process',
#   'accessible',
#   'candidates',
#   'require',
#   'special',
#   'assistance',
#   'accommodation',
#   'hiring',
#   'process',
#   'please',
#   'notify',
#   'member',
#   'hr',
#   'department'],
#  ['tiktok',
#   'leading',
#   'destination',
#   'shortform',
#   'mobile',
#   'video',
#   'mission',
#   'inspire',
#   'creativity',
#   'bring',
#   'joy',
#   'tiktok',
#   'global',
#   'offices',
#   'including',
#   'los',
#   'angeles',
#   'new',
#   'york',
#   'london',
#   'paris',
#   'berlin',
#   'dubai',
#   'mumbai',
#   'singapore',
#   'jakarta',
#   'seoul',
#   'tokyo',
#   'looking',
#   'talented',
#   'individuals',
#   'join',
#   'us',
#   '2022',
#   'people',
#   'want',
#   'inspire',
#   'creativity',
#   'cocreate',
#   'future',
#   'tiktok',
#   'internships',
#   'tiktok',
#   'aim',
#   'provide',
#   'students',
#   'chance',
#   'work',
#   'clients',
#   'teams',
#   'address',
#   'key',
#   'business',
#   'problems',
#   'identify',
#   'areas',
#   'growth',
#   'company',
#   'education',
#   'experience',
#   'able',
#   'take',
#   'realworld',
#   'challenges',
#   'day',
#   'one',
#   'applying',
#   'position',
#   'application',
#   'automatically',
#   'submitted',
#   'following',
#   'locations',
#   'san',
#   'francisco',
#   'new',
#   'york',
#   'austin',
#   'los',
#   'angeles',
#   'mountain',
#   'view',
#   'toronto',
#   'internship',
#   'program',
#   '12',
#   'weeks',
#   'duration',
#   'beginning',
#   'mayjune',
#   '2022',
#   'application',
#   'deadline',
#   'february',
#   '15th',
#   '2022',
#   'candidates',
#   'apply',
#   'maximum',
#   'two',
#   'positions',
#   'considered',
#   'jobs',
#   'order',
#   'apply',
#   'application',
#   'limit',
#   'firm',
#   'includes',
#   'campus',
#   'jobs',
#   'globally',
#   'applications',
#   'reviewed',
#   'rolling',
#   'basis',
#   'encourage',
#   'apply',
#   'early',
#   'monetization',
#   'office',
#   'organization',
#   'provides',
#   'business',
#   'critical',
#   'insights',
#   'using',
#   'analytics',
#   'ensures',
#   'cross',
#   'functional',
#   'alignment',
#   'goals',
#   'execution',
#   'helps',
#   'teams',
#   'drive',
#   'strategic',
#   'partnerships',
#   'new',
#   'initiatives',
#   'forward',
#   'stay',
#   'focused',
#   'aligning',
#   'highestlevel',
#   'company',
#   'priorities',
#   'effective',
#   'daytoday',
#   'operations',
#   'help',
#   'evolve',
#   'early',
#   'stage',
#   'ideas',
#   'futuregrowth',
#   'initiatives',
#   'looking',
#   'entrepreneurially',
#   'spirited',
#   'intern',
#   'join',
#   'monetization',
#   'strategy',
#   'team',
#   'us',
#   'role',
#   'responsible',
#   'driving',
#   'key',
#   'research',
#   'initiatives',
#   'within',
#   'team',
#   'including',
#   'developing',
#   'deep',
#   'understanding',
#   'digital',
#   'advertising',
#   'market',
#   'competitor',
#   'landscape',
#   'uncovering',
#   'critical',
#   'insights',
#   'business',
#   'responsibilities',
#   'collaborate',
#   'crossfunctional',
#   'stakeholders',
#   'develop',
#   'scalable',
#   'solutions',
#   'work',
#   'towards',
#   'consensus',
#   'across',
#   'organization',
#   'provide',
#   'objective',
#   'thorough',
#   'datadriven',
#   'recommendations',
#   'leadership',
#   'clear',
#   'actionable',
#   'suggestions',
#   'policy',
#   'teams',
#   'build',
#   'metrics',
#   'dashboards',
#   'tracking',
#   'strategies',
#   'inform',
#   'performance',
#   'conduct',
#   'indepth',
#   'analysis',
#   'helps',
#   'business',
#   'better',
#   'understand',
#   'key',
#   'value',
#   'drivers',
#   'growth',
#   'opportunities',
#   'effectively',
#   'communicate',
#   'actionable',
#   'insights',
#   'across',
#   'levels',
#   'inform',
#   'monetization',
#   'efforts',
#   'work',
#   'closely',
#   'crossfunctional',
#   'partners',
#   'including',
#   'local',
#   'monetization',
#   'teams',
#   'international',
#   'strategy',
#   'data',
#   'teams',
#   'drive',
#   'analytical',
#   'initiatives',
#   'completion',
#   'strong',
#   'research',
#   'analysis',
#   'skills',
#   'currently',
#   'pursuing',
#   'bachelors',
#   'master',
#   'degree',
#   'math',
#   'statistics',
#   'engineering',
#   'computer',
#   'science',
#   'quantitative',
#   'majors',
#   'preferred',
#   'able',
#   'commit',
#   'working',
#   '12',
#   'weeks',
#   'summer',
#   '2022',
#   'must',
#   'obtain',
#   'work',
#   'authorization',
#   'country',
#   'employment',
#   'time',
#   'hire',
#   'maintain',
#   'ongoing',
#   'work',
#   'authorization',
#   'employment',
#   'selfdriven',
#   'curious',
#   'passionate',
#   'involved',
#   'business',
#   'growing',
#   'fast',
#   'able',
#   'adapt',
#   'high',
#   'work',
#   'pace',
#   'ability',
#   'think',
#   'creatively',
#   'logically',
#   'structurally',
#   'summarize',
#   'patterns',
#   'complex',
#   'phenomena',
#   'strong',
#   'data',
#   'analysis',
#   'ability',
#   'able',
#   'use',
#   'excel',
#   'sql',
#   'tableau',
#   'data',
#   'analysis',
#   'visualization',
#   'tools',
#   'proficiently',
#   'proficient',
#   'one',
#   'programming',
#   'languages',
#   'python',
#   'r',
#   'getitdone',
#   'mindset',
#   'youre',
#   'motivated',
#   'work',
#   'hard',
#   'efficiently',
#   'fastpaced',
#   'crosscultural',
#   'environment',
#   'tiktok',
#   'committed',
#   'creating',
#   'inclusive',
#   'space',
#   'employees',
#   'valued',
#   'skills',
#   'experiences',
#   'unique',
#   'perspectives',
#   'platform',
#   'connects',
#   'people',
#   'across',
#   'globe',
#   'workplace',
#   'tiktok',
#   'mission',
#   'inspire',
#   'creativity',
#   'bring',
#   'joy',
#   'achieve',
#   'goal',
#   'committed',
#   'celebrating',
#   'diverse',
#   'voices',
#   'creating',
#   'environment',
#   'reflects',
#   'many',
#   'communities',
#   'reach',
#   'believe',
#   'individuals',
#   'shouldnt',
#   'disadvantaged',
#   'background',
#   'identity',
#   'instead',
#   'considered',
#   'based',
#   'strengths',
#   'experience',
#   'passionate',
#   'hope',
#   'tiktok',
#   'committed',
#   'providing',
#   'reasonable',
#   'accommodations',
#   'recruitment',
#   'process',
#   'need',
#   'assistance',
#   'accommodation',
#   'please',
#   'reach',
#   'us',
#   'accommodationsamstiktokcom'],
#  ['procter',
#   'gamble',
#   'looking',
#   'develop',
#   'next',
#   'generation',
#   'leaders',
#   'world',
#   'technology',
#   'currently',
#   'hiring',
#   '8',
#   '12month',
#   'digital',
#   'technologies',
#   'roles',
#   'starting',
#   'january',
#   '2022',
#   'may',
#   '2022',
#   'toronto',
#   'headquarters',
#   'passionate',
#   'data',
#   'technology',
#   'wish',
#   'learn',
#   'grow',
#   'continuously',
#   'career',
#   'pg',
#   'right',
#   'fit',
#   'learn',
#   'digital',
#   'technologies',
#   'internships',
#   'video',
#   'httpswwwyoutubecomwatchvqhuy7ahosoa',
#   'expect',
#   'expect',
#   'meaningful',
#   'work',
#   'day',
#   '1',
#   'depending',
#   'team',
#   'join',
#   'could',
#   'example',
#   'lead',
#   'projects',
#   'solve',
#   'challenging',
#   'supply',
#   'chain',
#   'problems',
#   'drive',
#   'digitization',
#   'initiatives',
#   'using',
#   'latest',
#   'technology',
#   'optimize',
#   'companys',
#   'go',
#   'market',
#   'strategy',
#   'apply',
#   'business',
#   'analytics',
#   'skills',
#   'improve',
#   'brand',
#   'building',
#   'experiences',
#   'among',
#   'interesting',
#   'opportunities',
#   'position',
#   'play',
#   'opportunity',
#   'deliver',
#   'results',
#   'measurable',
#   'real',
#   'business',
#   'value',
#   'build',
#   'relationships',
#   'collaborate',
#   'others',
#   'work',
#   'autonomously',
#   'teams',
#   'use',
#   'data',
#   'technology',
#   'innovation',
#   'drive',
#   'business',
#   'value',
#   'communicate',
#   'effectively',
#   'work',
#   'status',
#   'ask',
#   'others',
#   'help',
#   'remove',
#   'roadblocks',
#   'needed',
#   'support',
#   'providing',
#   'comprehensive',
#   'onboarding',
#   'get',
#   'know',
#   'company',
#   'role',
#   'expectations',
#   'perks',
#   'peers',
#   'continuously',
#   'providing',
#   'formal',
#   'informal',
#   'training',
#   'opportunities',
#   'coaching',
#   'mentorship',
#   'direct',
#   'manager',
#   'others',
#   'providing',
#   'honest',
#   'constructive',
#   'feedback',
#   'performance',
#   'throughout',
#   'internship',
#   'highlighting',
#   'opportunities',
#   'improvement',
#   'adding',
#   'new',
#   'hire',
#   'network',
#   'get',
#   'support',
#   'guidance',
#   'perspective',
#   'interns',
#   'recent',
#   'hires',
#   'similar',
#   'roles',
#   'giving',
#   'chance',
#   'take',
#   'part',
#   'diversity',
#   'networks',
#   'include',
#   'specific',
#   'networks',
#   'women',
#   'lgbtq',
#   'francophones',
#   'among',
#   'many',
#   'others',
#   'skills',
#   'traits',
#   'looking',
#   'passion',
#   'data',
#   'technology',
#   'proven',
#   'track',
#   'record',
#   'leadership',
#   'success',
#   'ability',
#   'build',
#   'relationships',
#   'work',
#   'diverse',
#   'multidisciplinary',
#   'teams',
#   'passion',
#   'continually',
#   'improving',
#   'capabilities',
#   'learning',
#   'new',
#   'things',
#   'superb',
#   'communication',
#   'problem',
#   'solving',
#   'analytical',
#   'skills',
#   'ability',
#   'handle',
#   'multiple',
#   'priorities',
#   'pressure',
#   'qualifications',
#   'would',
#   'make',
#   'great',
#   'fit',
#   'currently',
#   'studying',
#   'towards',
#   'bachelors',
#   'masters',
#   'degree',
#   'graduation',
#   'planned',
#   '2023',
#   '2024',
#   'available',
#   '8',
#   '12month',
#   'work',
#   'term',
#   'beginning',
#   'january',
#   '3rd',
#   '2022',
#   'may',
#   '2nd',
#   '2022',
#   'passion',
#   'data',
#   'technology',
#   'ability',
#   'build',
#   'relationships',
#   'work',
#   'diverse',
#   'multidisciplinary',
#   'teams',
#   'excellent',
#   'communication',
#   'problem',
#   'solving',
#   'analytical',
#   'skills',
#   'students',
#   'engineering',
#   'computer',
#   'science',
#   'mathematics',
#   'business',
#   'backgrounds',
#   'typically',
#   'found',
#   'roles',
#   'good',
#   'fit',
#   'interests',
#   'successful',
#   'interns',
#   'variety',
#   'disciplines',
#   'well',
#   'encourage',
#   'students',
#   'graduating',
#   '2023',
#   '2024',
#   'disciplines',
#   'apply',
#   'apply',
#   'please',
#   'apply',
#   'pg',
#   'careers',
#   'complete',
#   'application',
#   'assessments',
#   '1159',
#   'pm',
#   'tuesday',
#   'october',
#   '5',
#   '2021',
#   'encourage',
#   'review',
#   'hiring',
#   'process',
#   'starting',
#   'application',
#   'resume',
#   'submission',
#   'strong',
#   'resumes',
#   'use',
#   'contextactionresults',
#   'car',
#   'format',
#   'highlight',
#   'measurable',
#   'results',
#   'areas',
#   'leadership',
#   'data',
#   'analysis',
#   'achieved',
#   'previous',
#   'roles',
#   'experiences',
#   'cover',
#   'letters',
#   'transcripts',
#   'required',
#   'assessment',
#   'overview',
#   'skills',
#   'match',
#   'requirements',
#   'asked',
#   'complete',
#   'two',
#   'online',
#   'assessments',
#   'please',
#   'review',
#   'assessment',
#   'overview',
#   'information',
#   'prepare',
#   'assessment',
#   'scores',
#   'valid',
#   '12',
#   'months',
#   'apply',
#   'previous',
#   'scores',
#   'please',
#   'click',
#   'assessment',
#   'links',
#   'score',
#   'expired',
#   'prompted',
#   'rewrite',
#   'assessments',
#   'additional',
#   'information',
#   'pg',
#   'serves',
#   'nearly',
#   'five',
#   'billion',
#   'people',
#   'around',
#   'world',
#   'strongest',
#   'portfolio',
#   'trusted',
#   'quality',
#   'leadership',
#   'brands',
#   'including',
#   'tide',
#   'pantene',
#   'pampers',
#   'gillette',
#   'old',
#   'spice',
#   'join',
#   'us',
#   'grow',
#   'skills',
#   'worldclass',
#   'leader',
#   'pg',
#   'canada',
#   'named',
#   'one',
#   'canadas',
#   'top',
#   '100',
#   'employers',
#   '2021',
#   'canadas',
#   'top',
#   'employers',
#   'young',
#   'people',
#   '2021',
#   'canadas',
#   'best',
#   'diversity',
#   'employers',
#   '2021',
#   'equal',
#   'opportunity',
#   'employer',
#   'value',
#   'diversity',
#   'company',
#   'underrepresented',
#   'candidates',
#   'including',
#   'limited',
#   'people',
#   'disabilities',
#   'female',
#   'andor',
#   'black',
#   'indigenous',
#   'asian',
#   'latin',
#   'american',
#   'two',
#   'races',
#   'strongly',
#   'encouraged',
#   'apply',
#   'pg',
#   'committed',
#   'accommodating',
#   'applicant',
#   'disability',
#   'required',
#   'law',
#   'recruitment',
#   'assessment',
#   'selection',
#   'process',
#   'require',
#   'disability',
#   'related',
#   'accommodation',
#   'order',
#   'participate',
#   'recruitment',
#   'process',
#   'please',
#   'click',
#   'submit',
#   'request',
#   'sponsorship',
#   'work',
#   'authorization',
#   'available',
#   'role',
#   'applicants',
#   'responsibility',
#   'ensure',
#   'authorized',
#   'work',
#   'location',
#   'apply'],
#  ['position',
#   'description',
#   'soontobe',
#   'graduate',
#   'passion',
#   'tech',
#   'canadas',
#   'largest',
#   'consulting',
#   'firm',
#   'cgi',
#   'looking',
#   'innovative',
#   'tech',
#   'savvy',
#   'individuals',
#   'join',
#   'new',
#   'grad',
#   'tech',
#   'academies',
#   'looking',
#   'bright',
#   'energetic',
#   'individuals',
#   'support',
#   'client',
#   'journeys',
#   'highend',
#   'business',
#   'consulting',
#   'systems',
#   'integration',
#   'transformational',
#   'outsourcing',
#   'intellectual',
#   'property',
#   'new',
#   'grad',
#   'tech',
#   'academies',
#   'academies',
#   'opportunity',
#   'accelerate',
#   'learning',
#   'designated',
#   'tech',
#   'specializations',
#   'academies',
#   'run',
#   '518',
#   'weeks',
#   'designed',
#   'provide',
#   'depth',
#   'learning',
#   'set',
#   'success',
#   'move',
#   'new',
#   'role',
#   'participant',
#   'academy',
#   'join',
#   'cgi',
#   'cohort',
#   'new',
#   'graduates',
#   'part',
#   'learning',
#   'journey',
#   'work',
#   'individual',
#   'group',
#   'assignments',
#   'getting',
#   'coaching',
#   'guidance',
#   'trainers',
#   'representative',
#   'one',
#   'business',
#   'units',
#   'graduate',
#   'academy',
#   'join',
#   'team',
#   'within',
#   'designated',
#   'business',
#   'unit',
#   'start',
#   'applying',
#   'new',
#   'skills',
#   'learnings',
#   'new',
#   'grad',
#   'tech',
#   'academy',
#   'specializations',
#   'cloud',
#   'academy',
#   'testing',
#   'automation',
#   'academy',
#   'java',
#   'developer',
#   'academy',
#   'youre',
#   'looking',
#   'hit',
#   'ground',
#   'running',
#   'day',
#   'one',
#   'also',
#   'new',
#   'grad',
#   'opportunities',
#   'outside',
#   'academy',
#   'available',
#   'devops',
#   'developer',
#   'net',
#   'java',
#   'developers',
#   'future',
#   'duties',
#   'responsibilities',
#   'whether',
#   'new',
#   'grad',
#   'tech',
#   'academy',
#   'new',
#   'grad',
#   'position',
#   'cgi',
#   'provides',
#   'stellar',
#   'experience',
#   'new',
#   'grads',
#   'join',
#   'cgi',
#   'expect',
#   'fast',
#   'track',
#   'professional',
#   'development',
#   'become',
#   'top',
#   'consultant',
#   'access',
#   'professional',
#   'development',
#   'workshops',
#   'elearning',
#   'participate',
#   'new',
#   'grad',
#   'innovation',
#   'challenge',
#   'opportunity',
#   'work',
#   'crossfunctional',
#   'teams',
#   'coached',
#   'directors',
#   'vps',
#   'cash',
#   'prize',
#   'winning',
#   'team',
#   'gain',
#   'exposure',
#   'senior',
#   'leaders',
#   'networking',
#   'events',
#   'workshops',
#   'participate',
#   'social',
#   'events',
#   'peers',
#   'receive',
#   'regular',
#   'coaching',
#   'mentorship',
#   'leaders',
#   'salary',
#   'evaluations',
#   'based',
#   'performance',
#   'every',
#   '6',
#   'months',
#   'first',
#   '2',
#   'years',
#   'required',
#   'qualifications',
#   'successful',
#   'role',
#   'postsecondary',
#   'student',
#   'graduating',
#   'year',
#   'recent',
#   'grad',
#   'graduated',
#   'within',
#   'past',
#   '12',
#   'months',
#   'eligible',
#   'programs',
#   'computer',
#   'science',
#   'software',
#   'engineering',
#   'related',
#   'field',
#   'team',
#   'player',
#   'adapts',
#   'well',
#   'changing',
#   'needs',
#   'strong',
#   'interpersonal',
#   'skills',
#   'aptitude',
#   'innovation',
#   'relevant',
#   'work',
#   'experience',
#   'including',
#   'coops',
#   'internships',
#   'considered',
#   'asset',
#   'less',
#   '16',
#   'months',
#   'relevant',
#   'work',
#   'experience',
#   'excluding',
#   'coop',
#   'internships',
#   'expect',
#   'us',
#   'build',
#   'career',
#   'us',
#   'extraordinary',
#   'time',
#   'business',
#   'digital',
#   'transformation',
#   'continues',
#   'accelerate',
#   'cgi',
#   'center',
#   'changesupporting',
#   'clients',
#   'digital',
#   'journeys',
#   'offering',
#   'professionals',
#   'exciting',
#   'career',
#   'opportunities',
#   'cgi',
#   'success',
#   'comes',
#   'talent',
#   'commitment',
#   'professionals',
#   'one',
#   'team',
#   'share',
#   'challenges',
#   'rewards',
#   'come',
#   'growing',
#   'company',
#   'reinforces',
#   'culture',
#   'ownership',
#   'professionals',
#   'benefit',
#   'value',
#   'collectively',
#   'create',
#   'part',
#   'building',
#   'one',
#   'largest',
#   'independent',
#   'technology',
#   'business',
#   'services',
#   'firms',
#   'world',
#   'learn',
#   'cgi',
#   'wwwcgicom',
#   'unsolicited',
#   'agency',
#   'referrals',
#   'please',
#   'cgi',
#   'equal',
#   'opportunity',
#   'employer',
#   'addition',
#   'cgi',
#   'committed',
#   'providing',
#   'accommodations',
#   'people',
#   'disabilities',
#   'accordance',
#   'provincial',
#   'legislation',
#   'please',
#   'let',
#   'us',
#   'know',
#   'require',
#   'reasonable',
#   'accommodation',
#   'due',
#   'disability',
#   'aspect',
#   'recruitment',
#   'process',
#   'work',
#   'address',
#   'needs'],
#  ['req',
#   'id',
#   '316002',
#   'bell',
#   'build',
#   'worldclass',
#   'networks',
#   'develop',
#   'innovative',
#   'services',
#   'create',
#   'original',
#   'multiplatform',
#   'media',
#   'content',
#   'revolutionizing',
#   'canadians',
#   'communicate',
#   'youre',
#   'ready',
#   'bring',
#   'gamechanging',
#   'ideas',
#   'life',
#   'join',
#   'community',
#   'values',
#   'bold',
#   'ideas',
#   'professional',
#   'growth',
#   'employee',
#   'wellness',
#   'want',
#   'bell',
#   'team',
#   'bells',
#   'field',
#   'services',
#   'team',
#   'proud',
#   'face',
#   'bell',
#   'brand',
#   'performing',
#   'best',
#   'installation',
#   'repair',
#   'services',
#   'maintaining',
#   'bells',
#   'network',
#   'residential',
#   'business',
#   'customers',
#   'youre',
#   'passionate',
#   'driven',
#   'find',
#   'seeking',
#   'interesting',
#   'work',
#   'new',
#   'challenges',
#   'continuous',
#   'learning',
#   'opportunities',
#   'want',
#   'join',
#   'team',
#   'using',
#   'innovative',
#   'operational',
#   'theory',
#   'tools',
# ...
#   'calls',
#   'function',
#   'autonomy',
#   'idea',
#   'run',
#   'youll',
#   'encouraged',
#   'let',
#   'entrepreneurial',
#   'spirit',
#   'flourish',
#   'youll',
#   'work',
#   'incredible',
#   'teams',
#   'learn',
#   'contribute',
#   'support',
#   'every',
#   'step',
#   'way',
#   'klick',
#   'consciously',
#   'creating',
#   'culture',
#   'everyone',
#   'thrive',
#   'grow',
#   'careers',
#   'believe',
#   'best',
#   'work',
#   'comes',
#   'diverse',
#   'backgrounds',
#   'perspectives',
#   'skills',
#   'strongly',
#   'encourage',
#   'members',
#   'historically',
#   'underrepresented',
#   'communities',
#   'apply',
#   'including',
#   'black',
#   'people',
#   'indigenous',
#   'peoples',
#   'people',
#   'colour',
#   'people',
#   'disabilities',
#   'people',
#   'gender',
#   'sexually',
#   'diverse',
#   'communities',
#   'people',
#   'intersectional',
#   'identities',
#   'also',
#   'committed',
#   'developing',
#   'inclusive',
#   'barrierfree',
#   'recruitment',
#   'process',
#   'work',
#   'environment',
#   'require',
#   'accommodation',
#   'please',
#   'contact',
#   'us',
#   'careersklickcom',
#   'work',
#   'meet',
#   'accessibility',
#   'needs',
#   'ensure',
#   'positive',
#   'experience'],
#  ['validere',
#   'leading',
#   'data',
#   'analytics',
#   'saas',
#   'provider',
#   'accelerating',
#   'energy',
#   'transition',
#   'mission',
#   'digitally',
#   'transform',
#   'worlds',
#   'largest',
#   'supply',
#   'chain',
#   'commercially',
#   'environmentally',
#   'efficient',
#   'product',
#   'data',
#   'cloud',
#   'enables',
#   'energy',
#   'companies',
#   'aggregate',
#   'product',
#   'data',
#   'sources',
#   'single',
#   'source',
#   'truth',
#   'rapidly',
#   'seamlessly',
#   '40',
#   'leading',
#   'energy',
#   'companies',
#   'partnered',
#   'validere',
#   'identify',
#   'new',
#   'hidden',
#   'sources',
#   'value',
#   'across',
#   'business',
#   'unique',
#   'datasets',
#   'experts',
#   'across',
#   'data',
#   'science',
#   'physical',
#   'science',
#   'oil',
#   'gas',
#   'provide',
#   'clients',
#   'companywide',
#   'value',
#   'engine',
#   'boosts',
#   'commercial',
#   'margins',
#   'reduces',
#   'operational',
#   'costs',
#   'risks',
#   'ensures',
#   'meaningful',
#   'environmental',
#   'progress',
#   'founded',
#   'harvard',
#   'university',
#   'validere',
#   'since',
#   'raised',
#   '25m',
#   'leading',
#   'technology',
#   'energy',
#   'investors',
#   'including',
#   'wing',
#   'vc',
#   'greylock',
#   'partners',
#   'combinator',
#   'offices',
#   'houston',
#   'calgary',
#   'toronto',
#   '100',
#   'employees',
#   'focus',
#   'every',
#   'day',
#   'delivering',
#   'highest',
#   'value',
#   'removing',
#   'friction',
#   'scaling',
#   'results',
#   'every',
#   'one',
#   'customers',
#   'validere',
#   'mission',
#   'transform',
#   'worlds',
#   'largest',
#   'supply',
#   'chain',
#   'making',
#   'critical',
#   'product',
#   'quality',
#   'data',
#   'available',
#   'accessible',
#   'actionable',
#   'data',
#   'intelligence',
#   'platform',
#   'first',
#   'system',
#   'record',
#   'product',
#   'quality',
#   'oil',
#   'gas',
#   'bringing',
#   'disruptive',
#   'transparency',
#   'industry',
#   'underserved',
#   'technology',
#   '50',
#   'north',
#   'americas',
#   'leading',
#   'energy',
#   'companies',
#   'rely',
#   'valideres',
#   'insights',
#   'enhance',
#   'operational',
#   'trading',
#   'margins',
#   'reduce',
#   'waste',
#   'emissions',
#   'backed',
#   'notable',
#   'tech',
#   'energy',
#   'investors',
#   'including',
#   'wing',
#   'vc',
#   'greylock',
#   'partners',
#   'sallyport',
#   'combinator',
#   'offices',
#   'houston',
#   'calgary',
#   'toronto',
#   'team',
#   'growing',
#   'looking',
#   'people',
#   'think',
#   'outside',
#   'box',
#   'passion',
#   'learning',
#   'new',
#   'things',
#   'want',
#   'make',
#   'impact',
#   'growth',
#   'mindset',
#   'support',
#   'rapid',
#   'growth',
#   'looking',
#   'technical',
#   'success',
#   'analyst',
#   'passion',
#   'solving',
#   'complex',
#   'problems',
#   'related',
#   'customer',
#   'data',
#   'management',
#   'automation',
#   'customers',
#   'unique',
#   'custom',
#   'requirements',
#   'achieving',
#   'success',
#   'criteria',
#   'ideal',
#   'candidate',
#   'able',
#   'engineer',
#   'impactful',
#   'solutions',
#   'scale',
#   'delivering',
#   'excellent',
#   'level',
#   'customer',
#   'care',
#   'looking',
#   'someone',
#   'driven',
#   'excited',
#   'positive',
#   'impact',
#   'technology',
#   'business',
#   'data',
#   'management',
#   'activities',
#   'data',
#   'management',
#   'onboarding',
#   'new',
#   'customer',
#   'data',
#   'fielding',
#   'data',
#   'change',
#   'requests',
#   'customers',
#   'collaborative',
#   'inbox',
#   'work',
#   'technical',
#   'success',
#   'managers',
#   'consultants',
#   'ensure',
#   'incoming',
#   'data',
#   'correct',
#   'mapped',
#   'ensure',
#   'high',
#   'degree',
#   'fidelity',
#   'data',
#   'upload',
#   'verification',
#   'validation',
#   'change',
#   'requests',
#   'transformation',
#   'complex',
#   'wellbehaved',
#   'data',
#   'formats',
#   'transfer',
#   'onto',
#   'platform',
#   'stewardship',
#   'data',
#   'tooling',
#   'ability',
#   'use',
#   'existing',
#   'data',
#   'tooling',
#   'ownership',
#   'ensuring',
#   'adequate',
#   'tooling',
#   'requirements',
#   'communicated',
#   'engineering',
#   'teams',
#   'b',
#   'program',
#   'management',
#   'activities',
#   'coordinate',
#   'installation',
#   'connectivity',
#   'measurement',
#   'instrument',
#   'hardware',
#   'facilitate',
#   'organize',
#   'customer',
#   'data',
#   'usage',
#   'validere',
#   'software',
#   'platforms',
#   'bring',
#   'team',
#   'preferred',
#   'bachelors',
#   'degree',
#   'software',
#   'engineering',
#   'computer',
#   'science',
#   'stem',
#   'extensive',
#   'practical',
#   'experience',
#   'software',
#   'development',
#   '1',
#   'years',
#   'professional',
#   'experience',
#   'preferably',
#   'fastpaced',
#   'environment',
#   'startup',
#   'rapidly',
#   'growing',
#   'company',
#   'internship',
#   'experience',
#   'good',
#   'foundation',
#   'algorithms',
#   'data',
#   'structures',
#   'proficiency',
#   'python',
#   'numpy',
#   'scipy',
#   'panda',
#   'sql',
#   'comfortable',
#   'working',
#   'linux',
#   'writing',
#   'shell',
#   'scripts',
#   'strong',
#   'sense',
#   'ownership',
#   'accountability',
#   'job',
#   'seekers',
#   'choose',
#   'validere',
#   'competitive',
#   'compensation',
#   'comprehensive',
#   'health',
#   'benefits',
#   'stock',
#   'options',
#   'validere',
#   'owners',
#   'flexible',
#   'working',
#   'arrangements',
#   'professional',
#   'development',
#   'budget',
#   'master',
#   'craft',
#   'generous',
#   'timeoff',
#   'parentalfamily',
#   'leave',
#   'quarterly',
#   'employee',
#   'wellbeing',
#   'days',
#   'meeting',
#   'friday',
#   'afternoons',
#   'inclusive',
#   'egofree',
#   'environment',
#   'diversity',
#   'people',
#   'thought',
#   'valued',
#   'opportunity',
#   'impact',
#   'trajectory',
#   'fast',
#   'growing',
#   'tech',
#   'company',
#   'shared',
#   'values',
#   'deliver',
#   'highest',
#   'value',
#   'remove',
#   'friction',
#   'everyday',
#   'scalable',
#   'well',
#   'fair',
#   'transparent',
#   'validere',
#   'equal',
#   'employment',
#   'opportunity',
#   'employer',
#   'welcome',
#   'encourage',
#   'applications',
#   'everyone',
#   'regardless',
#   'race',
#   'colour',
#   'religion',
#   'gender',
#   'sexual',
#   'orientation',
#   'age',
#   'disability',
#   'status',
#   'accommodations',
#   'available',
#   'request',
#   'candidates',
#   'taking',
#   'part',
#   'aspects',
#   'interview',
#   'process',
#   'beyond',
#   'committed',
#   'providing',
#   'inclusive',
#   'open',
#   'diverse',
#   'work',
#   'environment'],
#  ['2',
#   'years',
#   'noninternship',
#   'professional',
#   'software',
#   'development',
#   'experience',
#   'programming',
#   'experience',
#   'least',
#   'one',
#   'modern',
#   'language',
#   'java',
#   'c',
#   'c',
#   'including',
#   'objectoriented',
#   'design',
#   '1',
#   'years',
#   'experience',
#   'contributing',
#   'architecture',
#   'design',
#   'architecture',
#   'design',
#   'patterns',
#   'reliability',
#   'scaling',
#   'new',
#   'current',
#   'systems',
#   'retail',
#   'capacity',
#   'control',
#   'team',
#   'seeks',
#   'passionate',
#   'resultsoriented',
#   'inventive',
#   'software',
#   'engineer',
#   'part',
#   'team',
#   'developers',
#   'building',
#   'large',
#   'scale',
#   'high',
#   'availability',
#   'software',
#   'systems',
#   'using',
#   'mathematical',
#   'modeling',
#   'simulations',
#   'data',
#   'analysis',
#   'looking',
#   'software',
#   'engineers',
#   'thrive',
#   'complex',
#   'problems',
#   'relish',
#   'challenge',
#   'operating',
#   'complex',
#   'mission',
#   'critical',
#   'systems',
#   'extreme',
#   'loads',
#   'think',
#   'challenge',
#   'successful',
#   'candidates',
#   'strong',
#   'leaders',
#   'prioritize',
#   'well',
#   'communicate',
#   'clearly',
#   'consistent',
#   'track',
#   'record',
#   'delivery',
#   'strong',
#   'candidate',
#   'understand',
#   'various',
#   'optimization',
#   'techniques',
#   'build',
#   'innovative',
#   'software',
#   'solutions',
#   'working',
#   'supply',
#   'chain',
#   'business',
#   'partners',
#   'delivering',
#   'viable',
#   'solution',
#   'enjoy',
#   'working',
#   'closely',
#   'peers',
#   'group',
#   'smart',
#   'talented',
#   'engineers',
#   'team',
#   'culture',
#   'encourages',
#   'innovation',
#   'expect',
#   'developers',
#   'management',
#   'alike',
#   'take',
#   'high',
#   'level',
#   'ownership',
#   'product',
#   'vision',
#   'technical',
#   'architecture',
#   'project',
#   'delivery',
#   'responsibilities',
#   'include',
#   'designing',
#   'developing',
#   'testing',
#   'troubleshooting',
#   'debugging',
#   'deploying',
#   'maintaining',
#   'documenting',
#   'delivering',
#   'largescale',
#   'highly',
#   'distributed',
#   'realtime',
#   'management',
#   'systems',
#   'core',
#   'effectively',
#   'managing',
#   'supply',
#   'chain',
#   'business',
#   'using',
#   'java',
#   'objectoriented',
#   'oo',
#   'design',
#   'patterns',
#   'nosql',
#   'dbs',
#   'data',
#   'modeling',
#   'techniques',
#   'gathering',
#   'analyzing',
#   'business',
#   'functional',
#   'requirements',
#   'translating',
#   'business',
#   'requirements',
#   'technical',
#   'design',
#   'specifications',
#   'serving',
#   'key',
#   'technical',
#   'resource',
#   'full',
#   'development',
#   'cycle',
#   'producing',
#   'comprehensive',
#   'usable',
#   'software',
#   'documentation',
#   'recommending',
#   'changes',
#   'development',
#   'maintenance',
#   'system',
#   'standards',
#   'working',
#   'agile',
#   'development',
#   'environment',
#   'always',
#   'working',
#   'important',
#   'stuff',
#   'hiring',
#   'coaching',
#   'mentoring',
#   'individuals',
#   'strong',
#   'computer',
#   'science',
#   'fundamentals',
#   'good',
#   'understanding',
#   'objectoriented',
#   'design',
#   'data',
#   'structures',
#   'algorithms',
#   'problem',
#   'solving',
#   'complexity',
#   'analysis',
#   'knowledge',
#   'sql',
#   'bachelors',
#   'advance',
#   'degree',
#   'computer',
#   'science',
#   'like',
#   'field',
#   'required',
#   'experience',
#   'building',
#   'largescale',
#   'faulttolerant',
#   'distributed',
#   'systems',
#   'familiarity',
#   'spring',
#   'web',
#   'services',
#   'nosql',
#   'dbs',
#   'experience',
#   'optimization',
#   'willingness',
#   'stages',
#   'development',
#   'process',
#   'design',
#   'testing',
#   'implementation',
#   'operational',
#   'support',
#   'willingness',
#   'work',
#   'agile',
#   'team',
#   'development',
#   'environment',
#   'excellent',
#   'interpersonal',
#   'communication',
#   'skills',
#   'submitting',
#   'application',
#   'apply',
#   'considered',
#   'multiple',
#   'software',
#   'engineer',
#   'openings',
#   'across',
#   'various',
#   'amazon',
#   'teams',
#   'successful',
#   'passing',
#   'initial',
#   'application',
#   'review',
#   'assessment',
#   'asked',
#   'submit',
#   'career',
#   'personal',
#   'preferences',
#   'dedicated',
#   'recruiters',
#   'match',
#   'right',
#   'role',
#   'based',
#   'preferences',
#   'amazon',
#   'committed',
#   'providing',
#   'accommodations',
#   'stages',
#   'recruitment',
#   'employment',
#   'accordance',
#   'applicable',
#   'human',
#   'rights',
#   'accommodation',
#   'legislation',
#   'contacted',
#   'employment',
#   'opportunity',
#   'advise',
#   'human',
#   'resources',
#   'require',
#   'accommodation',
#   'including',
#   'order',
#   'apply',
#   'position'],
#  ['stackadapt',
#   '1',
#   'performing',
#   'programmatic',
#   'advertising',
#   'platform',
#   'helping',
#   'brands',
#   'accelerate',
#   'customer',
#   'engagement',
#   'acquisition',
#   'stateoftheart',
#   'platform',
#   'progressive',
#   'work',
#   'machine',
#   'learning',
#   'meets',
#   'cuttingedge',
#   'user',
#   'experience',
#   'ranking',
#   'highest',
#   'performance',
#   'g2',
#   'crowd',
#   'fourth',
#   'time',
#   'one',
#   'fastestgrowing',
#   'companies',
#   'canada',
#   'ranks',
#   '6th',
#   'deloittes',
#   'technology',
#   'fast',
#   '50',
#   'ranking',
#   '23rd',
#   'fast',
#   '500',
#   'north',
#   'america',
#   'looking',
#   'add',
#   'data',
#   'engineers',
#   'data',
#   'team',
#   'team',
#   'works',
#   'solving',
#   'complex',
#   'problems',
#   'stackadapts',
#   'digital',
#   'advertising',
#   'platform',
#   'youll',
#   'working',
#   'directly',
#   'data',
#   'scientists',
#   'data',
#   'engineers',
#   'engineering',
#   'team',
#   'cto',
#   'building',
#   'pipelines',
#   'ad',
#   'optimization',
#   'models',
#   'databases',
#   'process',
#   'millions',
#   'requests',
#   'per',
#   'second',
#   'theres',
#   'shortage',
#   'data',
#   'problems',
#   'tackle',
#   'watch',
#   'talk',
#   'amazon',
#   'tech',
#   'talks',
#   'httpswwwyoutubecomwatchvlrqua4gpuu',
#   'youll',
#   'design',
#   'modular',
#   'scalable',
#   'data',
#   'pipelines',
#   'handle',
#   'huge',
#   'datasets',
#   'understand',
#   'implement',
#   'custom',
#   'ml',
#   'algorithms',
#   'work',
#   'microservice',
#   'architecture',
#   'simultaneously',
#   'implements',
#   'monitors',
#   'thousands',
#   'ml',
#   'models',
#   'concurrently',
#   'well',
#   'reaching',
#   'candidates',
#   'high',
#   'gpa',
#   'wellrespected',
#   'computer',
#   'science',
#   'program',
#   'confidence',
#   'algorithm',
#   'design',
#   'concurrency',
#   'preferably',
#   'least',
#   '1',
#   'year',
#   'job',
#   'experience',
#   'internships',
#   'count',
#   'interest',
#   'designing',
#   'distributed',
#   'scalable',
#   'systems',
#   'implementation',
#   'probabilistic',
#   'machine',
#   'learning',
#   'algorithms',
#   'algorithms',
#   'design',
#   'ability',
#   'stackadapters',
#   'enjoy',
#   'highly',
#   'competitive',
#   'salary',
#   'rrsp',
#   'matching',
#   '3',
#   'weeks',
#   'vacation',
#   '3',
#   'personal',
#   'care',
#   'days',
#   '1',
#   'volunteer',
#   'day',
#   'birthdays',
#   'full',
#   'benefits',
#   'league',
#   'day',
#   'one',
#   'employment',
#   'work',
#   'home',
#   'reimbursements',
#   'coverage',
#   'support',
#   'personal',
#   'development',
#   'initiatives',
#   'conferences',
#   'courses',
#   'etc',
#   'awesome',
#   'parental',
#   'leave',
#   'policy',
#   'weekly',
#   '15',
#   'lunch',
#   'credit',
#   'via',
#   'ritual',
#   'friendly',
#   'welcoming',
#   'supportive',
#   'culture',
#   'social',
#   'team',
#   'events',
#   'virtually',
#   'stackadapt',
#   'stackadapt',
#   'selfserve',
#   'programmatic',
#   'advertising',
#   'platform',
#   'used',
#   'exceptional',
#   'digital',
#   'marketers',
#   'stateoftheart',
#   'platform',
#   'progressive',
#   'work',
#   'machine',
#   'learning',
#   'meets',
#   'cuttingedge',
#   'user',
#   'experience',
#   'ad',
#   'buyers',
#   'plan',
#   'execute',
#   'manage',
#   'datadriven',
#   'digital',
#   'advertising',
#   'campaigns',
#   'across',
#   'devices',
#   'inventory',
#   'publisher',
#   'partners',
#   'stackadapt',
#   'top',
#   '100',
#   'software',
#   'product',
#   'g2',
#   'dsp',
#   'best',
#   'software',
#   'products',
#   'highest',
#   'satisfaction',
#   'lists',
#   'weve',
#   'recognized',
#   'high',
#   'performing',
#   'campaign',
#   'conversion',
#   'rates',
#   'awardwinning',
#   'customer',
#   'service',
#   'innovation',
#   'numerous',
#   'industry',
#   'publications',
#   'including',
#   'great',
#   'place',
#   'work',
#   'named',
#   'stackadapt',
#   'one',
#   'canadas',
#   'best',
#   'workplaces',
#   'startups',
#   '2021',
#   'leader',
#   'dsp',
#   'video',
#   'crosschannel',
#   'advertising',
#   'categories',
#   'g2',
#   'top',
#   'growing',
#   'company',
#   'canada',
#   'based',
#   'globe',
#   'mails',
#   '2020',
#   'business',
#   'report',
#   'named',
#   '23rd',
#   'deloitte',
#   'canadas',
#   'technology',
#   'fast',
#   '50',
#   'program',
#   'named',
#   'deloitte',
#   'technologys',
#   'fast',
#   '500',
#   'north',
#   'america',
#   'stackadapt',
#   'diverse',
#   'inclusive',
#   'team',
#   'collaborative',
#   'hardworking',
#   'individuals',
#   'trying',
#   'make',
#   'dent',
#   'universe',
#   'equal',
#   'opportunity',
#   'employer',
#   'happy',
#   'work',
#   'applicants',
#   'requesting',
#   'accommodation',
#   'stage',
#   'hiring',
#   'process',
#   'welcome',
#   'encourage',
#   'anyone',
#   'everyone',
#   'apply']]
